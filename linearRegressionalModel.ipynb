# %% [markdown]
# <h1><b>Normal Equation of Linear Regression</b></h1>

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(42)
X = np.random.randn(500,1)
y = 2*X + 1 + 1.2*np.random.randn(500,1)
X.shape, y.shape
print(x,y)
# Out:
# [[0.21893551]
#  [0.52123788]
#  [1.25212653]
#  [0.50758932]
#  [1.08150447]
#  [0.61402468]
#  [0.09191827]
#  [0.1351379 ]
#  [1.60371376]
#  [0.64110091]
#  [1.41613745]
#  [1.93444769]
#  [1.40904488]
#  [0.13369787]
#  [1.2341107 ]
#  [0.70270044]
#  [0.73784857]
#  [1.28313174]
#  [0.68549474]
#  [0.42613934]
#  [1.59990855]
#  [0.1565365 ]
#  [0.75909339]
#  [0.64670358]
#  [0.87350069]
#  [0.62969767]
#  [1.33758708]
#  [1.64368025]
#  [1.92737928]
#  [0.85312641]
#  [0.79316866]
#  [1.60069403]
#  [0.46851173]
#  [1.36192151]
#  [1.74025016]
#  [1.72474122]
#  [1.20888894]
#  [1.58108857]
#  [1.21314978]
#  [0.24766272]
#  [1.70360594]
#  [1.48864218]
#  [0.1786376 ]
#  [0.42027428]
#  [0.99883375]
#  [1.27309004]
#  [0.39389703]
#  [1.05208057]
#  [0.24975039]
#  [1.49526921]
#  [0.79970044]
#  [1.87236904]
#  [1.97333421]
#  [1.55174425]
#  [1.16280901]
#  [0.81960521]
#  [0.77660335]
#  [0.21927187]
#  [1.1939179 ]
#  [1.82563589]
#  [0.27765815]
#  [1.52413948]
# ...

# %% [markdown]
# <h3><b> Finding the Value of Theta</b></h3>
# <p>The theta which is being returned by the specific function is basically theta cap which minimizes the cost function </p>

# %%
def find_theta(X, y):
    
    m = X.shape[0] # Number of training examples. 
    # Appending a cloumn of ones in X to add the bias term.
    X = np.append(X, np.ones((m,1)), axis=1)    
    # reshaping y to (m,1)
    y = y.reshape(m,1)
    
    # The Normal Equation
    theta = np.dot(np.linalg.inv(np.dot(X.T, X)), np.dot(X.T, y))
    
    return theta

# %%
def predict(X):
    
    # Appending a cloumn of ones in X to add the bias term.
    X = np.append(X, np.ones((X.shape[0],1)), axis=1)
    
    # preds is y_hat which is the dot product of X and theta.
    preds = np.dot(X, theta)
    
    return preds

# %% [markdown]
# <b><h3>Non Predicted Data plot</h3></b>
# <p>This the plot of the cluster of data points on the graph the best-fit line is still not plotted</p>

# %%
theta= find_theta(X,y)
fig1= plt.figure(figsize=(8,6))
plt.plot(X, y, 'b.')

# %% [markdown]
# <h3><b>Predicted Data Points</b></h3>
# <p>This graph basically plots the best-fit line in which provides the values which are near to the data points and coincides with it </p>

# %%
# Getting the Value of theta using the find_theta function.
theta = find_theta(X, y)
fig = plt.figure(figsize=(8,6))
# Getting the predictions on X using the predict function.
preds = predict(X)
plt.plot(X, y, 'b.')
plt.plot(X, preds, 'c-')
plt.xlabel('X - Input')
plt.ylabel('y - target / true')
# Out:
# Text(0, 0.5, 'y - target / true')
